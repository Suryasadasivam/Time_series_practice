# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# 1. read data, filter using furniture
# sales and profit
# 2. min and max order date
# 3. convert column

# %%
#Load data 
df=pd.read_excel('Data/Superstore_Sales_Records.xls', index_col='Order Date',parse_dates=True)
df.head()
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                  State  Postal Code Region       Product ID         Category  \
# Order Date
# 2016-11-08    Kentucky        42420  South  FUR-BO-10001798        Furniture
# 2016-11-08    Kentucky        42420  South  FUR-CH-10000454        Furniture
# 2016-06-12  California        90036   West  OFF-LA-10000240  Office Supplies
# 2015-10-11     Florida        33311  South  FUR-TA-10000577        Furniture
# 2015-10-11     Florida        33311  South  OFF-ST-10000760  Office Supplies
#
#            Sub-Category                                       Product Name  \
# Order Date
# 2016-11-08    Bookcases                  Bush Somerset Collection Bookcase
# 2016-11-08       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2016-06-12       Labels  Self-Adhesive Address Labels for Typewriters b...
# 2015-10-11       Tables      Bretford CR4500 Series Slim Rectangular Table
# 2015-10-11      Storage                     Eldon Fold 'N Roll Cart System
#
#                Sales  Quantity  Discount    Profit
# Order Date
# 2016-11-08  261.9600         2      0.00   41.9136
# 2016-11-08  731.9400         3      0.00  219.5820
# 2016-06-12   14.6200         2      0.00    6.8714
# 2015-10-11  957.5775         5      0.45 -383.0310
# 2015-10-11   22.3680         2      0.20    2.5164

# %%
df. columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df=df[df['Category']=='Furniture']

# %%
df=df[['Sales','Profit']]

# %%
df.index
# Out:
# DatetimeIndex(['2016-11-08', '2016-11-08', '2015-10-11', '2014-06-09',
#                '2014-06-09', '2017-07-16', '2015-09-25', '2015-09-17',
#                '2015-09-17', '2016-12-08',
#                ...
#                '2015-11-13', '2016-06-03', '2016-12-12', '2017-06-01',
#                '2015-12-14', '2015-03-19', '2016-12-05', '2015-09-06',
#                '2014-01-21', '2017-02-26'],
#               dtype='datetime64[ns]', name='Order Date', length=2121, freq=None)

# %%
#check for min and max Order Date
df.index.min(), df.index.max()
# Out:
# (Timestamp('2014-01-06 00:00:00'), Timestamp('2017-12-30 00:00:00'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2121 entries, 2016-11-08 to 2017-02-26
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   2121 non-null   float64
#  1   Profit  2121 non-null   float64
# dtypes: float64(2)
# memory usage: 49.7 KB

# %%
df.columns
# Out:
# Index(['Sales', 'Profit'], dtype='object')

# %%
df['Profit'] = df['Profit'].astype('float32')
df['Sales'] = df['Sales'].astype('float32')

df.head()
# Out:
# /var/folders/j9/2xjjcspd5r3dz1m4ll_0c7m80000gn/T/ipykernel_4973/117650528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit'] = df['Profit'].astype('float32')
# /var/folders/j9/2xjjcspd5r3dz1m4ll_0c7m80000gn/T/ipykernel_4973/117650528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Sales'].astype('float32')
#                   Sales      Profit
# Order Date
# 2016-11-08   261.959991   41.913601
# 2016-11-08   731.940002  219.582001
# 2015-10-11   957.577515 -383.031006
# 2014-06-09    48.860001   14.169400
# 2014-06-09  1706.183960   85.309196

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2121 entries, 2016-11-08 to 2017-02-26
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   2121 non-null   float32
#  1   Profit  2121 non-null   float32
# dtypes: float32(2)
# memory usage: 33.1 KB

# %%
df.head(10)
# Out:
#                   Sales       Profit
# Order Date
# 2016-11-08   261.959991    41.913601
# 2016-11-08   731.940002   219.582001
# 2015-10-11   957.577515  -383.031006
# 2014-06-09    48.860001    14.169400
# 2014-06-09  1706.183960    85.309196
# 2017-07-16    71.372002    -1.019600
# 2015-09-25  1044.630005   240.264893
# 2015-09-17  3083.429932 -1665.052246
# 2015-09-17   124.199997    15.525000
# 2016-12-08   190.919998  -147.962997

# %% [markdown]
# Group the data over Order Date because we might have multiple furniture sales and profit values on same day. We can group the values over each day to get the cumulative sales and profit values per day

# %%
df=df.groupby(by="Order Date").agg({'Sales':sum,"Profit":sum})
# Out:
# /var/folders/j9/2xjjcspd5r3dz1m4ll_0c7m80000gn/T/ipykernel_4973/1099979467.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df=df.groupby(by="Order Date").agg({'Sales':sum,"Profit":sum})

# %%
df=df.sort_index()

# %%
df.head(5)
# Out:
#                   Sales      Profit
# Order Date
# 2014-01-06  2573.820068  746.407776
# 2014-01-07    76.727997  -53.709599
# 2014-01-10    51.939999   21.295401
# 2014-01-11     9.940000    3.081400
# 2014-01-13   879.938965   91.279800

# %%
df.columns
# Out:
# Index(['Sales', 'Profit'], dtype='object')

# %% [markdown]
# Data seems on daily frequency and we have data over span of 3 years that is we have too much points and it gonna bit harder to visualize the data. We can resample the data on month level to make it less granular and to get neat visualization.

# %%
df=df.resample('MS').sum()

# %%
df.head()
# Out:
#                    Sales       Profit
# Order Date
# 2014-01-01   6242.524902   805.466492
# 2014-02-01   1839.658081   120.691711
# 2014-03-01  14573.956055 -1128.655029
# 2014-04-01   7944.836914   554.380066
# 2014-05-01   6912.787109  -349.877625

# %% [markdown]
# Plotting

# %%
df.plot()
# Out:
# <Axes: xlabel='Order Date'>

# %%
df.plot().line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.plot().line
#
# AttributeError: 'Axes' object has no attribute 'line'

# %%
df['Sales'].plot()
# Out:
# <Axes: xlabel='Order Date'>

# %%
df['Profit'].plot()
# Out:
# <Axes: xlabel='Order Date'>

# %% [markdown]
# Plot formatting

# %%
title="Furniture Sales data"

df['Sales'].plot(title=title)
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %% [markdown]
# Figure size

# %%
fig_size=(12,8) #(height, width)

df["Sales"].plot(title=title,figsize=fig_size)
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %% [markdown]
# Axis labels

# %%
x_label="Order date"
y_label="Furniture_sales"

ax=df['Sales'].plot(title=title,figsize=fig_size)
ax.set(xlabel=x_label,ylabel=y_label)
# Out:
# [Text(0.5, 0, 'Order date'), Text(0, 0.5, 'Furniture_sales')]

# %% [markdown]
# X_LIMTS

# %%
df["Sales"]["2016-01-01":"2016-12-01"].plot(title=title,figsize=fig_size).autoscale(axis='x',tight=True)

# %%
#another way of x_limits 
df["Sales"].plot(title=title,figsize=fig_size,xlim=['2016-01-01','2016-12-01'])
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %% [markdown]
# y_limit

# %%
y_min=df["Sales"]['2016-01-01':'2016-12-01'].min()
y_max=df["Sales"]['2016-01-01':'2016-12-01'].max()

print(f'the minimum sales is {y_min} and the maximum sales is {y_max}')
# Out:
# the minimum sales is 3925.551025390625 and the maximum sales is 36678.71484375

# %%
df['Sales'].plot(title=title,figsize=fig_size,xlim=['2016-01-01','2016-12-01'],ylim=[y_min,y_max])
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %%
df['Sales'].plot(title=title,figsize=fig_size,xlim=['2016-01-01','2016-12-01'],ylim=[1000,y_max])
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %% [markdown]
# Color and Style

# %%
df['Sales'].plot(title=title, ls='--', c='g')
# Out:
# <Axes: title={'center': 'Furniture Sales data'}, xlabel='Order Date'>

# %% [markdown]
# X Ticks

# %%
from matplotlib import dates

# %%
ax = df['Sales'].plot(title=title, ls='-', c='g')

#remove the default `Data` label
ax.set(xlabel='')

ax.xaxis.set_major_locator(dates.MonthLocator(bymonthday=0))

# %%
ax = df['Sales'].plot(title=title, ls='-', c='g')

#remove the default `Data` label
ax.set(xlabel='')

ax.xaxis.set_major_locator(dates.MonthLocator(bymonthday=0))

# %%
ax = df['Sales'].plot(title=title, ls='-', c='g', xlim=['2016-01-01', '2016-12-01'], rot=45)

#remove the default `Data` label
ax.set(xlabel='')

ax.xaxis.set_major_locator(dates.YearLocator())

# %%
ax = df['Sales'].plot(title=title, ls='-', c='g', xlim=['2014-01-01', '2016-12-01'], rot=45)

#remove the default `Data` label
ax.set(xlabel='')

#major axis
ax.xaxis.set_major_locator(dates.YearLocator())

#set minor axis
ax.xaxis.set_minor_locator(dates.MonthLocator())

# %% [markdown]
# Adding Grid Lines

# %%
ax = df['Sales'].plot(title=title, ls='-', c='b', xlim=['2016-01-01', '2016-12-01'], rot=45)

#add grid lines

ax.xaxis.grid(True)
ax.yaxis.grid(True)
